# %% [markdown]
# ### Word Frequency and N-Grams

# %% [markdown]
# #### Import modules

# %%
import sys, os
import pandas as pd
sys.path.append(os.path.abspath(os.path.join('../scripts')))
from util import Util
# Out:
# c:\Users\Diriba\Desktop\10AC\Week7\LLM-Fine-Tuning-RAG\scripts\util.py:27: SyntaxWarning: invalid escape sequence '\-'
#   "\-"
# c:\Users\Diriba\Desktop\10AC\Week7\LLM-Fine-Tuning-RAG\scripts\util.py:28: SyntaxWarning: invalid escape sequence '\*'
#   "\*"
# c:\Users\Diriba\Desktop\10AC\Week7\LLM-Fine-Tuning-RAG\scripts\util.py:32: SyntaxWarning: invalid escape sequence '\_'
#   "\_"

# %%
cleaned_dir = "../data/cleaned"
final_dir = "../data/final"
file_name = "አዲስ ነገር መረጃ"
util = Util()

# %%
df = pd.read_csv(f"{cleaned_dir}/{file_name}.csv", index_col='id')
df.head()
# Out:
#                                                     text                 date  \
# id
# 11233  ህወሀት እንደ ቺቺኒያ ያሉ ለመኖርያ ተብለው በማስተር ፕላኑ የተቀመጡ ሰፈ...  2021-01-04T11:27:32
# 11258  የኤርትራ ውጭ ጉ/ሚንስትር እና የፕሬዝዳንት ኢሳይያስ አማካሪ የተካተቱበት...  2021-01-05T23:27:06
# 11259  ግብፃውያኑ በአባይ (በህዳሴ) ግድብ ጉዳይ ከመጨነቃቸው የተነሳ በቴሌቪዥን...  2021-01-06T08:23:56
# 11261  በአዲስ አበባ ፖፖላሬ አካባቢ በደረሰ የእሳት አደጋ ሁለት ተሽከርካሪዎች ...  2021-01-06T09:22:51
# 11262  የገና ሥጦታ ሎተሪ እጣ ውጤት  የገና ሥጦታ ሎተሪ ትላንት ማክሰኞ ታህሳስ...  2021-01-06T09:23:52
#
#            hashtags emojis symbols links   mentions
# id
# 11233            []    NaN       _    []  ['Addis']
# 11258            []    NaN       _    []  ['Addis']
# 11259            []  📍✒♦♦📌  """""_    []  ['Addis']
# 11261  ['#ዳጉ_ጆርናል']    NaN       _    []  ['Addis']
# 11262            []    NaN       _    []  ['Addis']

# %% [markdown]
# #### Word Frequency

# %%
# function to convert token to list and unpack
from functools import reduce
import operator


def term_freq(x):
    # Tokenize each text into words
    word_lists = [str(text).split() for text in x.tolist()]
    
    # Flatten the list of lists
    words = reduce(operator.add, word_lists)
    
    return words

# %%
# function to count the term/word and create a dataframe for frequencies
from collections import Counter

def counting(x, y):
  counter = Counter(x)
  most_occurrences = counter.most_common()
  count_df = pd.DataFrame(most_occurrences, columns = ['Word', 'Count'])
  return count_df

# %%
df_frequency = counting(term_freq(df['text']), 2)
df_frequency.head()
# Out:
#    Word  Count
# 0  News  20603
# 1    እና  19791
# 2    ላይ  16174
# 3    ወደ   7934
# 4    ነው   6095

# %% [markdown]
# #### Save word frequency

# %%
df_frequency.to_csv(f"{final_dir}/{file_name}_frequency.csv")

# %% [markdown]
# #### n-grams

# %%
import re


def list_and_tokenize(data):
    return str(data).split()

# %%
# function to prepare n-grams
import collections

def count_n_grams(lines, min_length=2, max_length=4):
    lengths = range(min_length, max_length + 1)
    n_grams = {length: collections.Counter() for length in lengths}
    queue = collections.deque(maxlen=max_length)

    # Helper function to add n-grams at start of current queue to dict
    def add_queue():
        current = tuple(queue)
        for length in lengths:
            if len(current) >= length:
                n_grams[length][current[:length]] += 1

    # Loop through all lines and words and add n-grams to dict
    for line in lines:
        for word in list_and_tokenize(line):
            # if len(word) > 3:
            queue.append(word)
            if len(queue) >= max_length:
                add_queue()

    # Make sure we get the n-grams at the tail end of the queue
    while len(queue) > min_length:
        queue.popleft()
        add_queue()

    return n_grams

# %%
bigram_to_df = pd.DataFrame({'2-grams': [], '2-grams freq': []})
trigram_to_df = pd.DataFrame({'3-grams': [], '3-grams freq': []})
quadgram_to_df = pd.DataFrame({'4-grams': [], '4-grams freq': []})

bigram = {'2-grams': [], '2-grams freq': []}
trigram = {'3-grams': [], '3-grams freq': []}
quadgram = {'4-grams': [], '4-grams freq': []}
    
def print_most_freq_ng(n_grams, num=30):
    global bigram_to_df, trigram_to_df, quadgram_to_df
    for n in sorted(n_grams):
        for gram, count in n_grams[n].most_common(num):
            if n == 2:
                bigram['2-grams'].append(gram)
                bigram['2-grams freq'].append(count)
            elif n == 3:
                trigram['3-grams'].append(gram)
                trigram['3-grams freq'].append(count)
            else:
                quadgram['4-grams'].append(gram)
                quadgram['4-grams freq'].append(count)
                
    bigram_to_df = pd.DataFrame({'2-grams': bigram['2-grams'], '2-grams freq': bigram['2-grams freq']})
    trigram_to_df = pd.DataFrame({'3-grams': trigram['3-grams'], '3-grams freq': trigram['3-grams freq']})
    quadgram_to_df = pd.DataFrame({'4-grams': quadgram['4-grams'], '4-grams freq': quadgram['4-grams freq']})

# %%
print_most_freq_ng(count_n_grams(df['text']))
n_gram_df = pd.concat([bigram_to_df, trigram_to_df, quadgram_to_df], axis=1)

n_gram_df
# Out:
#           2-grams  2-grams freq                      3-grams  3-grams freq  \
# 0    (News, News)          9689               (ቀን, 2015, ኣም)           373
# 1       (ምክር, ቤት)          1231             (የአዲስ, አበባ, ከተማ)           339
# 2     (በቁጥጥር, ስር)          1052           (ጠቅላይ, ሚኒስትር, አቢይ)           324
# 3     (የአዲስ, አበባ)          1009               (ቀን, 2013, ኣም)           312
# 4    (news, news)           950             (የአዲስ, አበባ, ፖሊስ)           291
# 5     (በአዲስ, አበባ)           933              (ወደ, ክልል, ከተሞች)           282
# 6       (ፍርድ, ቤት)           860                 (በ, 30, ደቂቃ)           281
# 7      (አዲስ, አበባ)           746         (አአ, ላላችሁትም, በእራሳችን)           279
# 8   (ጠቅላይ, ሚኒስትር)           716  (ላላችሁትም, በእራሳችን, transport)           279
# 9      (አበባ, ከተማ)           706    (በእራሳችን, transport, ያሉበት)           279
# 10  (ከተማ, አስተዳደር)           638       (transport, ያሉበት, ድረስ)           279
# 11     (የውጭ, ጉዳይ)           610               (ያሉበት, ድረስ, በ)           279
# 12    (በአማራ, ክልል)           602                 (ድረስ, በ, 30)           279
# 13   (በትግራይ, ክልል)           591           (30, ደቂቃ, እናደርሳለን)           279
# 14    (በዛሬው, እለት)           558           (ደቂቃ, እናደርሳለን, ወደ)           279
# 15    (የአማራ, ክልል)           552           (እናደርሳለን, ወደ, ክልል)           279
# 16      (ሙሉ, በሙሉ)           509            (ክልል, ከተሞች, በፖስታ)           279
# 17       (እኛ, ጋር)           502             (ከተሞች, በፖስታ, ቤት)           279
# 18     (ቀን, 2015)           502           (በፖስታ, ቤት, እንልካለን)           279
# 19     (ክፍለ, ከተማ)           470           (አበባ, ከተማ, አስተዳደር)           278
# 20      (ነገር, ግን)           444           (እንዲሁም, የብልት, ቁመት)           278
# 21     (2015, ኣም)           444               (ቀን, 2014, ኣም)           272
# 22   (የስንፈተ, ወሲብ)           441             (በአዲስ, አበባ, ከተማ)           270
# 23   (በኦሮሚያ, ክልል)           436             (ተወካዮች, ምክር, ቤት)           267
# 24    (የ12ኛ, ክፍል)           424            (ነው።, News, News)           251
# 25     (ቀን, 2014)           408           (የብልት, መጠንን, በዘላቂ)           248
# 26    (ለበለጠ, መረጃ)           406            (መጠንን, በዘላቂ, ሁኔታ)           248
# 27     (ቀን, 2013)           399           (በዘላቂ, ሁኔታ, ለመጨመር)           248
# 28    (ምንም, አይነት)           398         (ሁኔታ, ለመጨመር, በግንኙነት)           248
# 29   (ሚኒስትር, አቢይ)           395         (ለመጨመር, በግንኙነት, ወቅት)           248
#
#                               4-grams  4-grams freq
# 0     (አአ, ላላችሁትም, በእራሳችን, transport)           279
# 1   (ላላችሁትም, በእራሳችን, transport, ያሉበት)           279
# 2      (በእራሳችን, transport, ያሉበት, ድረስ)           279
# 3           (transport, ያሉበት, ድረስ, በ)           279
# 4                  (ያሉበት, ድረስ, በ, 30)           279
# 5                   (ድረስ, በ, 30, ደቂቃ)           279
# 6               (በ, 30, ደቂቃ, እናደርሳለን)           279
# 7              (30, ደቂቃ, እናደርሳለን, ወደ)           279
# 8             (ደቂቃ, እናደርሳለን, ወደ, ክልል)           279
# 9            (እናደርሳለን, ወደ, ክልል, ከተሞች)           279
# 10              (ወደ, ክልል, ከተሞች, በፖስታ)           279
# 11              (ክልል, ከተሞች, በፖስታ, ቤት)           279
# 12           (ከተሞች, በፖስታ, ቤት, እንልካለን)           279
# 13            (የብልት, መጠንን, በዘላቂ, ሁኔታ)           248
# 14           (መጠንን, በዘላቂ, ሁኔታ, ለመጨመር)           248
# 15         (በዘላቂ, ሁኔታ, ለመጨመር, በግንኙነት)           248
# 16          (ሁኔታ, ለመጨመር, በግንኙነት, ወቅት)           248
# 17           (ለመጨመር, በግንኙነት, ወቅት, ቶሎ)           248
# 18             (የተሻለ, የወሲብ, ፍላጎት, አና)           248
# 19              (የወሲብ, ፍላጎት, አና, ችሎታ)           248
# 20             (ፍላጎት, አና, ችሎታ, የሚጨምር)           248
# 21              (አና, ችሎታ, የሚጨምር, ብልት)           248
# 22             (ችሎታ, የሚጨምር, ብልት, ውጥር)           248
# 23              (የሚጨምር, ብልት, ውጥር, እና)           248
# 24                 (ብልት, ውጥር, እና, ቀጥ)           248
# 25                  (ውጥር, እና, ቀጥ, ብሎ)           248
# 26                (እና, ቀጥ, ብሎ, እንዲቆይ)           248
# 27          (የስንፈተ, ወሲብ, እንዲሁም, የብልት)           237
# 28            (ወሲብ, እንዲሁም, የብልት, ቁመት)           237
# 29           (እንዲሁም, የብልት, ቁመት, ማነስን)           237

# %% [markdown]
# #### Save n-grams

# %%
n_gram_df.to_csv(f"{final_dir}/{file_name}_n_gram.csv")
